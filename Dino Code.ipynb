# %%
from IPython.display import Image
import dinocode
import ipywidgets as widgets

# %%
text = widgets.Textarea(
    value="hi eli\n\ntry a fun note\n\nlove dad",
    description='String:',
    layout={'height': '200px', 'width': '400px'}
)
display(text)
# Out:
# Textarea(value='hi eli\n\ntry a fun note\n\nlove dad', description='String:', layout=Layout(height='200px', wi…

# %%
dinocode.encode(text.value)
# Out:
# <PIL.Image.Image image mode=RGB size=672x450 at 0x7B3AB05636A0>
